# %%
import pandas as pd
import numpy as np
import statistics as stat
import matplotlib.pyplot as plt
from scipy.signal import find_peaks # for detecting peaks

# %% [markdown]
# ## Part 1 - Product Bigrams Trend Analysis

# %%
# Open file
df = pd.read_excel("data/bigrams_for_trend_analysis.xlsx")

# group data frame by month and bigrams
df_grouped = df.groupby(['month','bigram'])['bigram'].count().unstack()

# replace the null values with 0
df_grouped.replace(np.nan, '0',inplace=True)
df_grouped = df_grouped.astype(int)
df_grouped
# Out:
# bigram   air fryer  baking soda  boiling water  butcher block  carbon steel  \
# month
# 2020-06          2            0              0              0             0
# 2020-07          3            2              2              0             0
# 2020-08          2            1              0              0             0
# 2020-09         46            0              1              0             0
# 2020-10          3            4              4              1             0
# 2020-11         35            2              2              2             1
# 2020-12          7            6              1             17            25
# 2021-01          2            3              1              1             0
# 2021-02          5            0              2              7             5
# 2021-03         15            0              0              2             1
# 2021-04          9            0              7              2             1
# 2021-05          4            0              1             19             1
# 2021-06         20            0              2              0             6
# 2021-07         22            1              2              3             1
# 2021-08          7            1              3              1             1
# 2021-09          4            0              9              1             1
# 2021-10         11            2              2             12             0
# 2021-11          9            5              1              0             1
# 2021-12          6            7              1              7            24
# 2022-01         13           33              9              3             2
# 2022-02          8           35              5              1             1
# 2022-03         16            6             47              4            17
# 2022-04         30            2              5              7             9
# 2022-05         24           18              4             29             6
#
# bigram   cast iron  cheese grater  cinnamon toast  classic vintage  \
# month
# 2020-06          0              0               0                0
# 2020-07          2              1               0                0
# 2020-08          0              0               0                0
# 2020-09         11              2               0                0
# 2020-10         26              0               0                0
# 2020-11          6              0               1                0
# 2020-12         22              1               0                0
# 2021-01         10              5               0                0
# 2021-02         28              3               0                0
# 2021-03         19              2               0                0
# 2021-04          7              1               2                0
# 2021-05         25              0               0                0
# 2021-06         57              0               0                0
# 2021-07         20              1               0                0
# 2021-08         20              7               0                0
# 2021-09          7              4               0                0
# 2021-10          6              1               0                0
# 2021-11         11              0               0                0
# 2021-12         44              1               0                0
# 2022-01         44              1               1                0
# 2022-02         38              1             305               71
# 2022-03         43              9              27                0
# 2022-04         59             11               6                0
# 2022-05         92             32               0                0
#
# bigram   corner cabinet  ...  rice dispenser  salt pepper  scrub daddy  \
# month                    ...
# 2020-06               0  ...               0            2            0
# 2020-07               1  ...               0            4            0
# 2020-08               1  ...               0            5            0
# 2020-09               5  ...               0            0            0
# 2020-10               2  ...               0            4            0
# 2020-11               1  ...               0            2            0
# 2020-12               0  ...               1            5            0
# 2021-01               2  ...               0            9            3
# 2021-02               6  ...               1            1            0
# 2021-03               4  ...               0            4            0
# 2021-04               0  ...               8           10            1
# 2021-05               0  ...               0            2            4
# 2021-06               1  ...               0            8            1
# 2021-07               1  ...               0           17            0
# 2021-08               3  ...               3            6            3
# 2021-09               1  ...               4           12            1
# 2021-10               0  ...               9           12            0
# 2021-11               4  ...               8            6            0
# 2021-12               7  ...               1            1            6
# 2022-01               5  ...               3            7           11
# 2022-02              18  ...               1          105           17
# 2022-03               5  ...               0           29            4
# 2022-04               7  ...              52           33           13
# 2022-05              34  ...              49           18           15
#
# bigram   spice cabinet  spice rack  stainless steel  toast crunch  \
# month
# 2020-06              1           7                5             0
# 2020-07              1          12                3             0
# 2020-08              0           1                1             0
# 2020-09              0           2                4             0
# 2020-10              0           4                3             0
# 2020-11              5           0                3             0
# 2020-12              0           5                7             0
# 2021-01              4          16                2             0
# 2021-02              3          13               37             0
# 2021-03              5           4               16             0
# 2021-04              2           9                9             1
# 2021-05              1           6               31             0
# 2021-06              4           2               73             0
# 2021-07              5           7               16             0
# 2021-08              2           4                9             0
# 2021-09              1           6               14             0
# 2021-10              1           6               11             0
# 2021-11              2           3               19             0
# 2021-12             15           5               44             0
# 2022-01              9          13               33             1
# 2022-02             40          58               28           298
# 2022-03              4          24               17            27
# 2022-04              3           6               58             5
# 2022-05              5          16               54             0
#
# bigram   useful tool  vacuum sealer  wood burning
# month
# 2020-06            0              0             0
# 2020-07            0              0             0
# 2020-08            0              0             0
# 2020-09            0              0             0
# 2020-10            0              0             0
# 2020-11            0              0             0
# 2020-12            0              0             0
# 2021-01            0              0             0
# 2021-02            0              0             1
# 2021-03            1              0             0
# 2021-04            0              0             0
# 2021-05            0              0             0
# 2021-06            3              0             0
# 2021-07            0              0             0
# 2021-08            0              0             0
# 2021-09            0              0             0
# 2021-10            0              0             0
# 2021-11            0              0             0
# 2021-12           62              0             0
# 2022-01            5              3             0
# 2022-02            0              0             0
# 2022-03            0            112             0
# 2022-04            0              0             0
# 2022-05            1              1           112
#
# [24 rows x 40 columns]

# %%
# This gives you all the bigrams in the dataframe
# you can only keep the bigrams you are interested in and paste them into the list in next box 
df_grouped.columns
# Out:
# Index(['air fryer', 'baking soda', 'boiling water', 'butcher block',
#        'carbon steel', 'cast iron', 'cheese grater', 'cinnamon toast',
#        'classic vintage', 'corner cabinet', 'counter tops', 'crunch seasoning',
#        'crunch spice', 'cumin powder', 'custom wood', 'cutting board',
#        'dining room', 'drying rack', 'dutch oven', 'empty space',
#        'expiration date', 'garlic powder', 'hot water', 'ice cream',
#        'meal prep', 'non stick', 'olive oil', 'paper towel', 'pot filler',
#        'potato salad', 'rice dispenser', 'salt pepper', 'scrub daddy',
#        'spice cabinet', 'spice rack', 'stainless steel', 'toast crunch',
#        'useful tool', 'vacuum sealer', 'wood burning'],
#       dtype='object', name='bigram')

# %%
# This is an option to customize your own list of bigrams
df_grouped = df_grouped[['air fryer', 'butcher block','carbon steel', 'cast iron', 'cheese grater', 
                         'corner cabinet', 'counter tops', 'cutting board', 'drying rack', 'dutch oven', 
                         'non stick', 'pot filler', 'rice dispenser', 'spice cabinet', 'spice rack', 
                         'stainless steel', 'vacuum sealer'
                        ]]

# %% [markdown]
# ### Trend Overview for all bigrams

# %%
# an overview of the graph of all bigrams
# fig,ax = plt.subplots(figsize=(15,9))
df_grouped.plot(figsize=(15,9))
plt.xticks(np.arange(len(df_grouped.index)), df_grouped.index, rotation=45)
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)

# %% [markdown]
# ### Trend Detection

# %%
# This is the month priod of detecting trend
detect_month = 6

# %%
# define a method to get slopes of the line
def getSlope(list_of_index, array_of_data, order=1):
    result = np.polyfit(range(len(list_of_index)), array_of_data, order)
    slope = result[-2]
    return float(slope)

# %% [markdown]
# ### Type 1: New Trend
# #### Criteira:
# 1. There are no data before 6 months (before 12/2021)
# 2. There are some data during the recent 6 months (after 12/2021)
# 3. The slope for 2-year data is upward

# %%
def newTrendDetector(df,detect_month,bigram_name):
    boo_list = []
    for value in df[bigram_name]:
        if value == 0:
            boo_list.append(0)
        else:
            boo_list.append(1)
    if sum(boo_list[:len(boo_list)-detect_month]) == 0 and sum(boo_list[-detect_month:]) != 0 and getSlope(df.index,df[bigram_name]) > 0:
        return True
    else:
        return False

# %% [markdown]
# ### Type 2: Peaked Trend
# #### Criteria:
#
# There is a peak during the recent 6 months (after 12/2021)

# %%
def peakedTrendDetector(df,detect_month,bigram_name):
    
    # method to get the peak value
    # define the value of prominence: 50% percent of the max value in the recent 6 months, 
    prominence = df[bigram_name][-detect_month:].max()*0.5
    peaks, _ = find_peaks(df[bigram_name][-detect_month:], prominence=prominence)
    
    # if there is a peak, return a list of peaked months
    if peaks.size > 0:        
        peaks, _ = find_peaks(df[bigram_name], prominence=prominence)
        
        peaked_months_l = []
        for peak in peaks:
            peaked_month = df.index[peak]
            peaked_months_l.append(peaked_month)
        return peaked_months_l
    
    else:
        return False

# %% [markdown]
# ### Type 3: Step Change
# #### Criteria:
# 1. There is no peak during the recent 6 months (after 12/2021)
# 2. There is some data before 6 months (before 12/2021)
# 3. The slope of the recent 6 months is positive

# %%
def stepChengeDetector(df,detect_month,bigram_name):

    
    # Make sure it is not a recent peaked trend
    if peakedTrendDetector(df,detect_month,bigram_name) == False:

        if sum(df[bigram_name][:len(df[bigram_name])-detect_month]) != 0 and getSlope(df.index[-detect_month:],df[bigram_name][-detect_month:]) > 0:
            return True
                
        else:
            return False
    else: 
        return False

# %%
# create lists to save the bigrams of each type of trend
new_trend_l = []
peaked_trend_l = []
step_change_l = []

# create a dictionary to save the bigrams' peaked month
bigram_and_peaked_months = {}

for bigram_name in df_grouped.columns:
    
    if newTrendDetector(df_grouped,detect_month,bigram_name) != False:
        new_trend_bigram = bigram_name
        new_trend_l.append(new_trend_bigram)
        
    if peakedTrendDetector(df_grouped,detect_month,bigram_name) != False:
        peaked_bigram = bigram_name
        peaked_trend_l.append(peaked_bigram)
        bigram_and_peaked_months[bigram_name] = peakedTrendDetector(df_grouped,detect_month,bigram_name)
        
    if stepChengeDetector(df_grouped,detect_month,bigram_name) != False:
        step_change_bigram = bigram_name
        step_change_l.append(step_change_bigram)

# %%
new_trend_l
# Out:
# ['vacuum sealer']

# %%
peaked_trend_l
# Out:
# ['drying rack',
#  'dutch oven',
#  'pot filler',
#  'spice cabinet',
#  'spice rack',
#  'vacuum sealer']

# %%
step_change_l
# Out:
# ['air fryer',
#  'butcher block',
#  'cast iron',
#  'cheese grater',
#  'corner cabinet',
#  'counter tops',
#  'cutting board',
#  'non stick',
#  'rice dispenser',
#  'stainless steel']

# %%
# Define a method to save bigrams trend graph to local folder
def saveTrendFig(df_grouped, trend_type, bigram_list):
    
    for bigram in bigram_list:
        df_single_bigram = df_grouped[[bigram]]
        
        df_single_bigram.plot(figsize=(15,9))
        plt.title(bigram,fontsize=20)
        plt.legend().set_visible(False)
        # plt.gcf().autofmt_xdate()
        plt.xticks(np.arange(len(df_grouped.index)), df_grouped.index, rotation=45)
        
        plt.savefig('data/graphs/bigrams/{} ({}).png'.format(trend_type,bigram), facecolor = 'white')
        plt.close()

# %%
# save graphs of new trend bigrams
saveTrendFig(df_grouped, 'new_trend', new_trend_l)

# save graphs of peaked trend bigrams
saveTrendFig(df_grouped, 'peaked_trend', peaked_trend_l)

# save graphs of new trend bigrams
saveTrendFig(df_grouped, 'step_change', step_change_l)

# %% [markdown]
# ### Get video links of the peaked bigrams

# %%
# dictionary of peaked bigrams and their peaked months
bigram_and_peaked_months
# Out:
# {'drying rack': ['2022-02'],
#  'dutch oven': ['2020-10', '2021-02', '2022-02'],
#  'pot filler': ['2021-04', '2021-07', '2022-01'],
#  'spice cabinet': ['2022-02'],
#  'spice rack': ['2022-02'],
#  'vacuum sealer': ['2022-03']}

# %%
# open the comments dataframe
comments_df = pd.read_excel('data/comments_all_clean.xlsx')
comments_df[:10]
# Out:
#             c_video_id           comment_id  comment_timestamp  \
# 0  7082050405420551466  7082056310845539115         1648919735
# 1  7082050405420551466  7082081883085374214         1648925687
# 2  7082050405420551466  7085158385347511083         1649641992
# 3  7082050405420551466  7082191775650399022         1648951276
# 4  7082050405420551466  7090005163238900523         1650770475
# 5  7082050405420551466  7089813843930022702         1650725931
# 6  7082050405420551466  7088144220594668331         1650337187
# 7  7082050405420551466  7098311373763445510         1652704412
# 8  7082050405420551466  7089438929711203118         1650638640
# 9  7082050405420551466  7087345239284106030         1650151161
#
#                                         comment_text     text_string  \
# 0    i'm running in circles!!! where do i run to????     running run
# 1  the fact that there was still some egg on the ...  fact egg plate
# 2               the caption 😭 sounds like a 1950s ad         caption
# 3  why didn’t you poured all the egg , it’s bothe...             egg
# 4   every woman's dream? y'all ain't dreaming right!           woman
# 5         you could’ve pour all of the egg in there…        pour egg
# 6  i love everything except cooking 1 pancake at ...  except pancake
# 7           why didn’t you use all the egg mixture 😳     egg mixture
# 8  why is it every woman’s dream? my husband usua...           woman
# 9              what do you mean by that. the caption         caption
#
#                    text_token    month
# 0          ['running', 'run']  2022-04
# 1    ['fact', 'egg', 'plate']  2022-04
# 2           ['caption', 'ad']  2022-04
# 3                     ['egg']  2022-04
# 4                   ['woman']  2022-04
# 5             ['pour', 'egg']  2022-04
# 6  ['except', '1', 'pancake']  2022-04
# 7          ['egg', 'mixture']  2022-05
# 8                   ['woman']  2022-04
# 9                 ['caption']  2022-04

# %%
# open the video dataframe to get the videos information
videos_df = pd.read_excel("data/videos_all_clean.xlsx")
videos_df.replace(np.nan, '',inplace=True)
videos_df
# Out:
#                   video_id  video_timestamp  likes_count  comments_count  \
# 0      6919824641510984965       1611147259       426900            2207
# 1      6891620407367994626       1604580417         7849              44
# 2      6889388819049647361       1604060835         6464              25
# 3      6871212488822656257       1599828829         5465              34
# 4      6901266520828120321       1606826328         5134              16
# ...                    ...              ...          ...             ...
# 10206  6962739399196937478       1621139102           59               1
# 10207  6841040327818759430       1592803829           52              17
# 10208  7001319000948903173       1630121611           51               3
# 10209  6950489866169748742       1618287037           97              15
# 10210  7052917005246139695       1642135207           69               5
#
#                                                video_url  \
# 0      https://www.tiktok.com/@mamaandkidz/video/6919...
# 1      https://www.tiktok.com/@evichou17/video/689162...
# 2      https://www.tiktok.com/@evichou17/video/688938...
# 3      https://www.tiktok.com/@evichou17/video/687121...
# 4      https://www.tiktok.com/@evichou17/video/690126...
# ...                                                  ...
# 10206  https://www.tiktok.com/@darknsexydragonlady/vi...
# 10207  https://www.tiktok.com/@bestamazonprimecodes/v...
# 10208  https://www.tiktok.com/@rcstiktoktv/video/7001...
# 10209  https://www.tiktok.com/@carolineschulze5/video...
# 10210  https://www.tiktok.com/@jeffreyrubel/video/705...
#
#                                               video_desc  \
# 0      #mylife #mylifeas #minitoys #baking #bakingset...
# 1      Renyah dan wangi🤤#kekinian #viral #fyp #foryou...
# 2      Bolu kukus pop ice #bolukukus #popice #bolu #t...
# 3      Asik nih buat yg suka ngemil #bakingset@steinc...
# 4      Tanpa SP, ekonomis dan praktis #icecream #@cho...
# ...                                                  ...
# 10206  #duet with @foodies #beautiful🐢 #ocd #utensils...
# 10207  Price drop no code needed #amazon #amazoncodes...
# 10208  What is this? #fypシ #wierd #utensils #kitchen ...
# 10209  i support radical utensils #college#fyp #stitc...
# 10210  Reply to @jeffreyrubel Forky!! And a little ba...
#
#                                         video_transcript  \
# 0
# 1      begin you yapping couple muscle T-Mobile choco...
# 2                              Goosebumps eyes in Europe
# 3
# 4
# ...                                                  ...
# 10206
# 10207
# 10208                            kitchen utensil is this
# 10209  nobody literally like this is going to change ...
# 10210  adorable little toy from Toy Story 4 plastic u...
#
#                                              text_string    month
# 0                                                         2021-01
# 1                                                         2020-11
# 2                                                pop ice  2020-10
# 3                                                         2020-09
# 4                                                         2020-12
# ...                                                  ...      ...
# 10206                                                     2021-05
# 10207                                               drop  2020-06
# 10208                                            utensil  2021-08
# 10209                      support radical nobody change  2021-04
# 10210  forky plastic mainly forky adorable toy toy st...  2022-01
#
# [10211 rows x 9 columns]

# %%
def getVideoRefDF(videos_df, comments_df, bigram_months_dic):
    

    bigram_l = []
    month_l = []
    video_id_l = []
    
    # Step 1
    # check each comment, see if it contains the biagram
    # save the bigram name, month, and video id
    
    for i,comment_text in enumerate(comments_df['comment_text']):
        
        for bigram in bigram_months_dic:
            
            for month in bigram_months_dic[bigram]:
                
                if comments_df['month'][i] == month and bigram in comment_text:
                    bigram_l.append(bigram)
                    month_l.append(month)
                    video_id_l.append(comments_df['c_video_id'][i])
                    
    # Step 2
    # check the video text for each video, see if it contains the bigram
    # save the bigram name, month, and video id
                    
    for i,video_text in enumerate(videos_df['text_string']):
        
        for bigram in bigram_months_dic:
            
            for month in bigram_months_dic[bigram]:
                
                if videos_df['month'][i] == month and bigram in video_text:
                    bigram_l.append(bigram)
                    month_l.append(month)
                    video_id_l.append(videos_df['video_id'][i])
                
    # Step 3
    # create a dataframe and save the above information
    ref_videos_dic = {'bigram': bigram_l,
                      'month': month_l,
                      'video_id': video_id_l,
                      }
    ref_videos_df = pd.DataFrame(ref_videos_dic)
    
    # add a column shows how many times the bigram is mentioned in the comments for each video
    ref_videos_df = ref_videos_df.value_counts().reset_index(name='bigram_mentioned_times')
    ref_videos_df
    
    
    # Step 4
    # join the previous generated dataframe with some column in the video dataframe by video id
    ref_videos_df = pd.merge(ref_videos_df, videos_df[['video_id','likes_count','comments_count','video_url','video_desc','video_transcript']], on="video_id")
    
    # drop the video id column (not useful)
    ref_videos_df = ref_videos_df.drop(columns=['video_id'])
    
    # sort by bigram name, month, and the times that bigram is mentioned in the comments
    ref_videos_df = ref_videos_df.sort_values(by=['bigram', 'month','bigram_mentioned_times'], ascending = [True, True, False], ignore_index=True)
    
    return ref_videos_df

# %%
# get the videos reference data frame for the peaked bigrams
peaked_videos_df = getVideoRefDF(videos_df, comments_df, bigram_and_peaked_months)
peaked_videos_df
# Out:
#            bigram    month  bigram_mentioned_times  likes_count  \
# 0     drying rack  2022-02                       3         4743
# 1     drying rack  2022-02                       2         2424
# 2     drying rack  2022-02                       1         8823
# 3     drying rack  2022-02                       1           94
# 4     drying rack  2022-02                       1           27
# ..            ...      ...                     ...          ...
# 70     spice rack  2022-02                       1       196800
# 71     spice rack  2022-02                       1        14900
# 72     spice rack  2022-02                       1          151
# 73     spice rack  2022-02                       1          209
# 74  vacuum sealer  2022-03                     119       131100
#
#     comments_count                                          video_url  \
# 0              139  https://www.tiktok.com/@yourlifeiswhatyoumakei...
# 1               15  https://www.tiktok.com/@byjamiemichelle/video/...
# 2              508  https://www.tiktok.com/@yourlifeiswhatyoumakei...
# 3                1  https://www.tiktok.com/@idyllickitchen/video/7...
# 4                0  https://www.tiktok.com/@handykitchensupplies/v...
# ..             ...                                                ...
# 70            1106  https://www.tiktok.com/@thewoodworks/video/702...
# 71              49  https://www.tiktok.com/@everythingenvy/video/7...
# 72              39  https://www.tiktok.com/@cwhatsheeats/video/705...
# 73               3  https://www.tiktok.com/@thejennataylor/video/7...
# 74             862  https://www.tiktok.com/@aldiallthetime/video/7...
#
#                                            video_desc  \
# 0   Reply to @jendelaisla #amazon #amazonfinds #si...
# 1   Obsessed! Linked ‘em for ya! #kitchenhacks #ki...
# 2   DIY kitchen makeover #diy #diyer #diykitchen #...
# 3   Kitchen with Ease. ❤️ Store Link in Bio. 😊 or ...
# 4   My new Handy Sink Drying Rack has made drying ...
# ..                                                ...
# 70  One of our new favourites, what do you like ab...
# 71  Like & follow for all the best organizing tips...
# 72  I should have made it as a “lazy” cook. Anyone...
# 73  Kitchen essentials 🤍 #kitchenware #kitchenesse...
# 74  Home finds out this week! #homedecor #kitchenw...
#
#                                      video_transcript
# 0   here is the video of the scene that we got it ...
# 1   we have been loving and our first home this dr...
# 2                                      wait wait wait
# 3   more counter space for giant Rincon or cooling...
# 4   with me I used to just put my clean dishes on ...
# ..                                                ...
# 70                                         I love you
# 71  if you are not very for the day it cannot alwa...
# 72               turn the Luna Mensa matter Mamma Mia
# 73  that make me happy these last months something...
# 74
#
# [75 rows x 8 columns]

# %%
# save to local folder
peaked_videos_df.to_excel('data/peaked_bigrams_video_reference.xlsx', index=False)

# %% [markdown]
# ## Part 2 - Color Bigrams Trend Analysis

# %%
# Open color bigram file
df_color = pd.read_excel('data/color_bigrams_for_trend_analysis.xlsx')

# group data frame by month and bigrams
df_color_grouped = df_color.groupby(['month','bigram'])['bigram'].count().unstack()

# replace the null values with 0
df_color_grouped.replace(np.nan, '0',inplace=True)
df_color_grouped = df_color_grouped.astype(int)
df_color_grouped
# Out:
# bigram   black glass  black set  blue plate  blue steel  brown granite  \
# month
# 2020-07            0          0           0           0              0
# 2020-08            0          0           0           0              0
# 2020-09            0          1           0           0              0
# 2020-10            0          0           0           0              0
# 2020-11            0          2           0           0              0
# 2020-12            0          0           0           1              0
# 2021-01            0          1           1           0              0
# 2021-02            0          1           0           0              1
# 2021-03            0          1           0           0              0
# 2021-04            0          0           0           0              0
# 2021-05            1          0           1           0              0
# 2021-06            0          0           0           1              0
# 2021-08            0          1           0           0              0
# 2021-09            0          0           0           0              0
# 2021-10            0          2           0           0              2
# 2021-11            0          0           0           0              0
# 2021-12            0          0           0           1              0
# 2022-01            0          3           0           0              1
# 2022-02            1          0           0           0              1
# 2022-03            2          1           0           2              0
# 2022-04            1          0           0           0              4
# 2022-05            2          2          20           0              4
#
# bigram   gold flatware  gold handle  gold set  green pan  pewter green  \
# month
# 2020-07              0            0         0          0             0
# 2020-08              0            0         0          0             0
# 2020-09              0            0         0          0             0
# 2020-10              0            3         1          0             0
# 2020-11              1            0         0          0             0
# 2020-12              0            0         0          1             0
# 2021-01              0            0         0          0             0
# 2021-02              0            0         0          0             0
# 2021-03              0            0         1          4             0
# 2021-04              2            2         2          0             0
# 2021-05              2            0         0          3             0
# 2021-06              0            0         0          1             0
# 2021-08              0            1         0          0             0
# 2021-09              0            0         0          0             0
# 2021-10              0            0         0          0             0
# 2021-11              0            0         1          0             0
# 2021-12              0            0         0          3             0
# 2022-01              3            0         0          6             8
# 2022-02              0            0         0          0            13
# 2022-03              2            1         1          1             0
# 2022-04              0            0         1          0             1
# 2022-05              1            3         6          1             1
#
# bigram   pink pan  pink set  purple utensil  red chopper  yellow bowl
# month
# 2020-07         1         6               0            0            0
# 2020-08         0         0               0            1            0
# 2020-09         0         0               0            0            0
# 2020-10         5         0               0            0            0
# 2020-11         0         1               0            0            0
# 2020-12         0         2               0            0            0
# 2021-01         0         2               0            0            0
# 2021-02         1         0               0            0            0
# 2021-03         1         0               0            0            0
# 2021-04         0         0               0            0            0
# 2021-05         0         1               0            0            0
# 2021-06         0         1               0            1            0
# 2021-08         0         0               0            0            0
# 2021-09         1         0               0            0            0
# 2021-10         0         0               0            0            0
# 2021-11         0         0               0            0            0
# 2021-12         0         0               0            0            0
# 2022-01         2         1               0            1            0
# 2022-02         0         0               1            3            0
# 2022-03         0         4               0            0            3
# 2022-04         2         6               0            0            0
# 2022-05         0         1               0            1            0

# %%
# an overview of the graph of all color bigrams
# fig,ax = plt.subplots(figsize=(15,9))
df_color_grouped.plot(figsize=(15,9))
plt.xticks(np.arange(len(df_color_grouped.index)), df_color_grouped.index, rotation=45)
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)

# %% [markdown]
# ## Get video links of color bigrams
# As shown in the above chart, the color bigrams are not mentioned as many times as the product bigrams. Therefore, we decided no to use the trend analysis.
#
# Instead, we set a threshold value if a bigram is mentioned more than the threshold value in a month, we provide the video links of the videos in that month.

# %%
# you can change the threshold
threshold = 10

# %%
# get the color bigrams mentioned more than the threshold and the months

color_bigram_and_months = {}

for color_bigram in df_color_grouped.columns:
    
    months = []
    for i, mentioned_times in enumerate(df_color_grouped[color_bigram]):
        if mentioned_times > threshold:
            months.append(df_color_grouped.index[i])
    
    if months: # if the list is not null
        color_bigram_and_months[color_bigram] = months

color_bigram_and_months
# Out:
# {'blue plate': ['2022-05'], 'pewter green': ['2022-02']}

# %%
# get the video reference data frame of color bigrams
color_videos_df = getVideoRefDF(videos_df, comments_df, color_bigram_and_months)
color_videos_df
# Out:
#          bigram    month  bigram_mentioned_times  likes_count  comments_count  \
# 0    blue plate  2022-05                      20         8208             168
# 1  pewter green  2022-02                       9        35700             559
# 2  pewter green  2022-02                       4         8823             508
#
#                                            video_url  \
# 0  https://www.tiktok.com/@mississippi_kween/vide...
# 1  https://www.tiktok.com/@yourlifeiswhatyoumakei...
# 2  https://www.tiktok.com/@yourlifeiswhatyoumakei...
#
#                                           video_desc video_transcript
# 0  #tartarsauce #tartar #sauce #homemade #cooktok...
# 1  I dub this the #paintstickchallenge  #paintsti...
# 2  DIY kitchen makeover #diy #diyer #diykitchen #...   wait wait wait

# %%
# save to local folder
color_videos_df.to_excel('data/color_bigrams_video_reference.xlsx', index=False)
